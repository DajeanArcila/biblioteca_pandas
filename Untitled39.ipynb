# %% [markdown]
# <a href="https://colab.research.google.com/github/DajeanArcila/biblioteca_pandas/blob/main/Untitled39.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# %pip install kmodes

# %%
# Dataviz
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from sklearn.cluster import k_means, dbscan, mean_shift, estimate_bandwidth
from sklearn.cluster import KMeans

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
# Didatic purposes
import string
from ipywidgets import interact

# %%
from kmodes.kmodes import KModes            # clustering categorical data
from kmodes.kprototypes import KPrototypes  # clustering mixed data
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
import pandas as pd
import numpy as np

# Configuración de la semilla para reproducibilidad
np.random.seed(42)

# Número de empleados
num_employees = 1000

# Generar datos ficticios
data = {
    'Edad': np.random.randint(22, 60, size=num_employees),
    'Salario': np.random.randint(30000, 120000, size=num_employees),
    'Satisfacción Laboral': np.random.randint(1, 11, size=num_employees),
    'Horas Trabajadas': np.random.randint(30, 60, size=num_employees),
    'Departamento': np.random.choice(['Ventas', 'Finanzas', 'Marketing',], size=num_employees),
    'Antigüedad': np.random.randint(1, 20, size=num_employees)
}

# Crear DataFrame
df_employees = pd.DataFrame(data)

# Mostrar las primeras filas del DataFrame
print(df_employees.head())

# Guardar en un archivo CSV
df_employees.to_csv('datos_empleados.csv', index=False)
# Out:
#    Edad  Salario  Satisfacción Laboral  Horas Trabajadas Departamento  \
# 0    50    32717                     7                35       Ventas
# 1    36    89676                     9                57     Finanzas
# 2    29    57952                     1                50       Ventas
# 3    42   116444                     7                51       Ventas
# 4    40    72460                     8                40       Ventas
#
#    Antigüedad
# 0           2
# 1           9
# 2          13
# 3          16
# 4          18

# %%
df = df_employees
df.head()
# Out:
#    Edad  Salario  Satisfacción Laboral  Horas Trabajadas Departamento  \
# 0    50    32717                     7                35       Ventas
# 1    36    89676                     9                57     Finanzas
# 2    29    57952                     1                50       Ventas
# 3    42   116444                     7                51       Ventas
# 4    40    72460                     8                40       Ventas
#
#    Antigüedad
# 0           2
# 1           9
# 2          13
# 3          16
# 4          18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Edad                  1000 non-null   int64
#  1   Salario               1000 non-null   int64
#  2   Satisfacción Laboral  1000 non-null   int64
#  3   Horas Trabajadas      1000 non-null   int64
#  4   Departamento          1000 non-null   object
#  5   Antigüedad            1000 non-null   int64
# dtypes: int64(5), object(1)
# memory usage: 47.0+ KB

# %%
df = pd.get_dummies(df, columns=['Departamento'], drop_first=False)

# %%
# https://matplotlib.org/stable/tutorials/introductory/customizing.html
sns.set_theme(
    context='talk',
    style='ticks',
    font_scale=.8,
    palette='tab10',
    rc={
        'figure.figsize': (12,8),
        'axes.grid': True,
        'grid.alpha': .2,
        'axes.titlesize': 'x-large',
        'axes.titleweight': 'bold',
        'axes.titlepad': 20,
    }
)

scatter_kwargs = dict(palette='viridis', alpha=0.8, linewidth=0)

# %%
X= df[['Salario','Edad']]
y= df['Satisfacción Laboral']

# %%
# Calcular el Within-Cluster Sum of Squares (WCSS) para diferentes valores de k
wcss = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, init='k-means++', max_iter=300, n_init=10, random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# Graficar el método del codo
plt.figure(figsize=(10,6))
plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
plt.title('Método del Codo')
plt.xlabel('Número de Clústeres')
plt.ylabel('WCSS')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Edad                    1000 non-null   int64
#  1   Salario                 1000 non-null   int64
#  2   Satisfacción Laboral    1000 non-null   int64
#  3   Horas Trabajadas        1000 non-null   int64
#  4   Antigüedad              1000 non-null   int64
#  5   Departamento_Finanzas   1000 non-null   bool
#  6   Departamento_Marketing  1000 non-null   bool
#  7   Departamento_Ventas     1000 non-null   bool
# dtypes: bool(3), int64(5)
# memory usage: 42.1 KB

# %%
# Seleccionar columnas relevantes
X = df[['Edad','Salario','Satisfacción Laboral','Horas Trabajadas','Antigüedad']]
# Preprocesar los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Determinar el número de clusters (por ejemplo, 3)
kmeans = KMeans(n_clusters=4, random_state=0)
df['cluster'] = kmeans.fit_predict(X_scaled)

# Visualizar los resultados (usando 2D o 3D si es necesario)
plt.scatter(df['Salario'], df['Edad'], c=df['cluster'], cmap='viridis')
plt.xlabel('Salario')
plt.ylabel('Edad')
plt.title('Clusters')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
