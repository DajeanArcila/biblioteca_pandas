# %% [markdown]
# <a href="https://colab.research.google.com/github/DajeanArcila/biblioteca_pandas/blob/main/arvores_desicao_visual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#em este código usamos arbol de clasificacion pero plotamos los resultados a ver como trabaja el modelo y que variables causan mas impacto em la clasificacion o desicion

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df =pd.read_excel('vendas.xlsx')

# %%
df.head()
# Out:
#    media_rating  media_pedidos test cliente_comprou
# 0           1.5             11   No             Yes
# 1           2.5             11   No              No
# 2           2.5             11   No              No
# 3           1.5             13   No             Yes
# 4           2.5             13   No              No

# %%
#definomos el X y Y para saber cual es nuestra variable target
x = df[['media_rating','media_pedidos'	,'test']]

y= df[['cliente_comprou']]

# %%
#pasamos a variable numerica las que aun no son
x=pd.get_dummies(x)
x.head()
# Out:
#    media_rating  media_pedidos  test_No  test_Yes
# 0           1.5             11     True     False
# 1           2.5             11     True     False
# 2           2.5             11     True     False
# 3           1.5             13     True     False
# 4           2.5             13     True     False

# %%
#importamos biblioteca, entrenamos nuestros datos

from sklearn import tree

arvore_decisao = tree.DecisionTreeClassifier()

modelo_ad = arvore_decisao.fit(x, y)
modelo_ad
# Out:
# DecisionTreeClassifier()

# %%
#plotamos resultados
fig = plt.figure(figsize=(40,18))

fig = tree.plot_tree(modelo_ad,
                   feature_names=x.columns,
                   class_names=['yes', "no"],
                   filled=True)
