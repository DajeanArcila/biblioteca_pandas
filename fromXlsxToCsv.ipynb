# %% [markdown]
# <a href="https://colab.research.google.com/github/DajeanArcila/biblioteca_pandas/blob/main/fromXlsxToCsv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Ruta al archivo de Excel
ruta_excel = '/content/BaseDeDatosLista aaaaaaaaaaaaaaa.xlsx'

# Leer el archivo de Excel
df = pd.read_excel(ruta_excel)

# Ruta al archivo CSV donde se guardará el resultado
ruta_csv = 'sample_data.csv'

# Guardar el DataFrame como CSV
df.to_csv(ruta_csv, index=False)

print(f'Archivo convertido y guardado en {ruta_csv}')
# Out:
# Archivo convertido y guardado en sample_data.csv

# %%
df= pd.read_csv('sample_data.csv')
df.head()
# Out:
#          Data  Último  Abertura  Máxima  Mínima   Vol/    Var%        DATA  \
# 0  2024-04-30  5.1934    5.1190  5.1975  5.1133  95.19  0.0146  2024-04-30
# 1  2024-04-29  5.1189    5.1170  5.1227  5.1020  95.19  0.0007  2024-04-29
# 2  2024-04-26  5.1151    5.1615  5.1673  5.1085  95.19 -0.0087  2024-04-26
# 3  2024-04-25  5.1602    5.1472  5.1935  5.1099  95.19  0.0028  2024-04-25
# 4  2024-04-24  5.1457    5.1263  5.1720  5.1238  95.19  0.0038  2024-04-24
#
#    RESERVAS
# 0   351.599
# 1   351.599
# 2   351.599
# 3   351.599
# 4   351.599
