# %% [markdown]
# <a href="https://colab.research.google.com/github/DajeanArcila/biblioteca_pandas/blob/main/regresion_logistica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
from sklearn.linear_model import LogisticRegression

import pandas as pd

# %%
df= pd.read_excel('/content/golf_df.xlsx')

# %%
df.head()
# Out:
#       clima  temp umidade vento jogar
# 0     sunny   hot    high    no    no
# 1     sunny   hot    high   yes    no
# 2  overcast   hot    high    no   yes
# 3     rainy  mild    high    no   yes
# 4     rainy  cool  normal    no   yes

# %%
#normalizamos las variables explicativas de nuestra target

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

le.fit(df.clima)
df.clima= le.transform(df.clima)

le.fit(df.temp)
df.temp= le.transform(df.temp)

le.fit(df.vento)
df.vento= le.transform(df.vento)

le.fit(df.umidade)
df.umidade= le.transform(df.umidade)

le.fit(df.jogar)
df.jogar= le.transform(df.jogar)

# %%
x = df.iloc[:,:-1]
y = df[['jogar']]

# %%
model = LogisticRegression()
model.fit(x,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
predict= model.predict(x)

# %%
x['predict']= predict

y= pd.DataFrame(y)

x['real']= y['jogar']

x.head()
# Out:
#    clima  temp  umidade  vento  predict  real
# 0      2     1        0      0        0     0
# 1      2     1        0      1        0     0
# 2      0     1        0      0        1     1
# 3      1     2        0      0        1     1
# 4      1     0        1      0        1     1
